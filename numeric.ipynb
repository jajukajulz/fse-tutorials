# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('synthetic_asset_prices.csv')
df.head()
df.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('synthetic_asset_prices.csv')
df.head()
df.plot.bar()
# Out:
# <Axes: >
